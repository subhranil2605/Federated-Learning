# %%
# !pip install syft==0.2.9

# %%
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import time
import copy
import numpy as np
import syft as sy

# %%
import syft.frameworks.torch.fl.utils as utils
from syft.workers.websocket_client import WebsocketClientWorker

# %%
class Parser:
    def __init__(self):
        self.epochs = 100
        self.lr = 0.001
        self.test_batch_size = 8
        self.batch_size = 8
        self.log_interval = 10
        self.seed = 1
    
args = Parser()
torch.manual_seed(args.seed)

# %%
with open('/content/boston_housing.pickle','rb') as f:
    ((x, y), (x_test, y_test)) = pickle.load(f)

x = torch.from_numpy(x).float()
y = torch.from_numpy(y).float()
x_test = torch.from_numpy(x_test).float()
y_test = torch.from_numpy(y_test).float()

# %%
mean = x.mean(0, keepdim=True)
dev = x.std(0, keepdim=True)
mean[:, 3] = 0.
dev[:, 3] = 1.
x = (x - mean) / dev
x_test = (x_test - mean) / dev
train = TensorDataset(x, y)
test = TensorDataset(x_test, y_test)
train_loader = DataLoader(train, batch_size=args.batch_size, shuffle=True)
test_loader = DataLoader(test, batch_size=args.test_batch_size, shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(13, 32)
        self.fc2 = nn.Linear(32, 24)
        self.fc4 = nn.Linear(24, 16)
        self.fc3 = nn.Linear(16, 1)

    def forward(self, x):
        x = x.view(-1, 13)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc4(x))
        x = self.fc3(x)
        return x

# %%
hook = sy.TorchHook(torch)
bob_worker = sy.VirtualWorker(hook, id="bob")
alice_worker = sy.VirtualWorker(hook, id="alice")
# kwargs_websocket = {"host": "localhost", "hook": hook}
# alice = WebsocketClientWorker(id='alice', port=8779, **kwargs_websocket)
# bob = WebsocketClientWorker(id='bob', port=8778, **kwargs_websocket)
compute_nodes = [bob_worker, alice_worker]
# Out:
# WARNING:root:Torch was already hooked... skipping hooking process

# %%
remote_dataset = (list(), list())
train_distributed_dataset = []

for batch_idx, (data,target) in enumerate(train_loader):
    data = data.send(compute_nodes[batch_idx % len(compute_nodes)])
    target = target.send(compute_nodes[batch_idx % len(compute_nodes)])
    remote_dataset[batch_idx % len(compute_nodes)].append((data, target))

# %%
bobs_model = Net()
alices_model = Net()
bobs_optimizer = optim.SGD(bobs_model.parameters(), lr=args.lr)
alices_optimizer = optim.SGD(alices_model.parameters(), lr=args.lr)

# %%
models = [bobs_model, alices_model]
optimizers = [bobs_optimizer, alices_optimizer]

# %%
model = Net()
model
# Out:
# Net(
#   (fc1): Linear(in_features=13, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=24, bias=True)
#   (fc4): Linear(in_features=24, out_features=16, bias=True)
#   (fc3): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
def update(data, target, model, optimizer):
    model.send(data.location)
    optimizer.zero_grad()
    prediction = model(data)
    loss = F.mse_loss(prediction.view(-1), target)
    loss.backward()
    optimizer.step()
    return model

def train():
    for data_index in range(len(remote_dataset[0])-1):
        for remote_index in range(len(compute_nodes)):
            data, target = remote_dataset[remote_index][data_index]
            models[remote_index] = update(data, target, models[remote_index], optimizers[remote_index])
        for model in models:
            model.get()
        return utils.federated_avg({
            "bob": models[0],
            "alice": models[1]
        })

# %%
def test(federated_model):
    federated_model.eval()
    test_loss = 0
    for data, target in test_loader:
        output = federated_model(data)
        test_loss += F.mse_loss(output.view(-1), target, reduction='sum').item()
        predection = output.data.max(1, keepdim=True)[1]
        
    test_loss /= len(test_loader.dataset)
    print('Test set: Average loss: {:.4f}'.format(test_loss))

# %%
for epoch in range(args.epochs):
    start_time = time.perf_counter()
    print(f"Epoch Number {epoch + 1}")
    federated_model = train()
    model = federated_model
    test(federated_model)
    total_time = time.perf_counter() - start_time
    print('Communication time over the network', round(total_time, 2), 's\n')
# Out:
# Epoch Number 1
# Test set: Average loss: 615.5769
# Communication time over the network 0.07 s
#
# Epoch Number 2
# Test set: Average loss: 606.6520
# Communication time over the network 0.07 s
#
# Epoch Number 3
# Test set: Average loss: 605.8724
# Communication time over the network 0.08 s
#
# Epoch Number 4
# Test set: Average loss: 609.3896
# Communication time over the network 0.07 s
#
# Epoch Number 5
# Test set: Average loss: 604.7644
# Communication time over the network 0.07 s
#
# Epoch Number 6
# Test set: Average loss: 604.5383
# Communication time over the network 0.07 s
#
# Epoch Number 7
# Test set: Average loss: 592.8397
# Communication time over the network 0.07 s
#
# Epoch Number 8
# Test set: Average loss: 601.2558
# Communication time over the network 0.07 s
#
# Epoch Number 9
# Test set: Average loss: 591.0329
# Communication time over the network 0.08 s
#
# Epoch Number 10
# Test set: Average loss: 593.6671
# Communication time over the network 0.07 s
#
# Epoch Number 11
# Test set: Average loss: 594.8978
# Communication time over the network 0.08 s
#
# Epoch Number 12
# Test set: Average loss: 586.0259
# Communication time over the network 0.07 s
#
# Epoch Number 13
# Test set: Average loss: 581.6632
# Communication time over the network 0.07 s
#
# Epoch Number 14
# Test set: Average loss: 582.4151
# Communication time over the network 0.07 s
#
# Epoch Number 15
# Test set: Average loss: 576.1746
# Communication time over the network 0.09 s
#
# Epoch Number 16
# Test set: Average loss: 579.0480
# Communication time over the network 0.07 s
#
# Epoch Number 17
# Test set: Average loss: 560.0133
# Communication time over the network 0.08 s
#
# Epoch Number 18
# Test set: Average loss: 559.9063
# Communication time over the network 0.08 s
#
# Epoch Number 19
# Test set: Average loss: 556.9069
# Communication time over the network 0.08 s
#
# Epoch Number 20
# Test set: Average loss: 547.6248
# Communication time over the network 0.07 s
#
# Epoch Number 21
# Test set: Average loss: 540.9025
# Communication time over the network 0.08 s
#
# Epoch Number 22
# Test set: Average loss: 538.7495
# Communication time over the network 0.07 s
#
# Epoch Number 23
# Test set: Average loss: 525.3472
# Communication time over the network 0.07 s
#
# Epoch Number 24
# Test set: Average loss: 512.1150
# Communication time over the network 0.07 s
#
# Epoch Number 25
# Test set: Average loss: 510.9306
# Communication time over the network 0.08 s
#
# Epoch Number 26
# Test set: Average loss: 512.0455
# Communication time over the network 0.07 s
#
# Epoch Number 27
# Test set: Average loss: 474.3960
# Communication time over the network 0.07 s
#
# Epoch Number 28
# Test set: Average loss: 453.8858
# Communication time over the network 0.07 s
#
# Epoch Number 29
# Test set: Average loss: 456.9726
# Communication time over the network 0.07 s
#
# Epoch Number 30
# Test set: Average loss: 447.1466
# Communication time over the network 0.07 s
#
# Epoch Number 31
# Test set: Average loss: 414.5911
# Communication time over the network 0.07 s
#
# Epoch Number 32
# Test set: Average loss: 422.1998
# Communication time over the network 0.07 s
#
# Epoch Number 33
# Test set: Average loss: 398.9749
# Communication time over the network 0.07 s
#
# Epoch Number 34
# Test set: Average loss: 417.0813
# Communication time over the network 0.07 s
#
# Epoch Number 35
# Test set: Average loss: 384.0751
# Communication time over the network 0.07 s
#
# Epoch Number 36
# Test set: Average loss: 395.1402
# Communication time over the network 0.07 s
#
# Epoch Number 37
# Test set: Average loss: 375.4868
# Communication time over the network 0.08 s
#
# Epoch Number 38
# Test set: Average loss: 381.0960
# Communication time over the network 0.07 s
#
# Epoch Number 39
# Test set: Average loss: 325.8911
# Communication time over the network 0.08 s
#
# Epoch Number 40
# Test set: Average loss: 359.1057
# Communication time over the network 0.08 s
#
# Epoch Number 41
# Test set: Average loss: 348.2914
# Communication time over the network 0.07 s
#
# Epoch Number 42
# Test set: Average loss: 315.9479
# Communication time over the network 0.07 s
#
# Epoch Number 43
# Test set: Average loss: 321.5847
# Communication time over the network 0.07 s
#
# Epoch Number 44
# Test set: Average loss: 332.3693
# Communication time over the network 0.07 s
#
# Epoch Number 45
# Test set: Average loss: 317.6832
# Communication time over the network 0.07 s
#
# Epoch Number 46
# Test set: Average loss: 337.6674
# Communication time over the network 0.07 s
#
# Epoch Number 47
# Test set: Average loss: 319.0721
# Communication time over the network 0.07 s
#
# Epoch Number 48
# Test set: Average loss: 335.3260
# Communication time over the network 0.07 s
#
# Epoch Number 49
# Test set: Average loss: 310.4291
# Communication time over the network 0.08 s
#
# Epoch Number 50
# Test set: Average loss: 317.3200
# Communication time over the network 0.07 s
#
# Epoch Number 51
# Test set: Average loss: 307.5275
# Communication time over the network 0.08 s
#
# Epoch Number 52
# Test set: Average loss: 277.3542
# Communication time over the network 0.07 s
#
# Epoch Number 53
# Test set: Average loss: 307.0427
# Communication time over the network 0.08 s
#
# Epoch Number 54
# Test set: Average loss: 330.9965
# Communication time over the network 0.07 s
#
# Epoch Number 55
# Test set: Average loss: 337.8003
# Communication time over the network 0.07 s
#
# Epoch Number 56
# Test set: Average loss: 327.2205
# Communication time over the network 0.07 s
#
# Epoch Number 57
# Test set: Average loss: 318.7950
# Communication time over the network 0.07 s
#
# Epoch Number 58
# Test set: Average loss: 316.5913
# Communication time over the network 0.08 s
#
# Epoch Number 59
# Test set: Average loss: 307.6550
# Communication time over the network 0.07 s
#
# Epoch Number 60
# Test set: Average loss: 322.6920
# Communication time over the network 0.07 s
#
# Epoch Number 61
# Test set: Average loss: 294.5586
# Communication time over the network 0.07 s
#
# Epoch Number 62
# Test set: Average loss: 326.1831
# Communication time over the network 0.07 s
#
# Epoch Number 63
# Test set: Average loss: 308.8820
# Communication time over the network 0.07 s
#
# Epoch Number 64
# Test set: Average loss: 320.5841
# Communication time over the network 0.07 s
#
# Epoch Number 65
# Test set: Average loss: 299.8881
# Communication time over the network 0.07 s
#
# Epoch Number 66
# Test set: Average loss: 315.7553
# Communication time over the network 0.08 s
#
# Epoch Number 67
# Test set: Average loss: 342.8560
# Communication time over the network 0.07 s
#
# Epoch Number 68
# Test set: Average loss: 331.5647
# Communication time over the network 0.08 s
#
# Epoch Number 69
# Test set: Average loss: 307.9678
# Communication time over the network 0.07 s
#
# Epoch Number 70
# Test set: Average loss: 300.6726
# Communication time over the network 0.07 s
#
# Epoch Number 71
# Test set: Average loss: 296.1563
# Communication time over the network 0.07 s
#
# Epoch Number 72
# Test set: Average loss: 294.3425
# Communication time over the network 0.07 s
#
# Epoch Number 73
# Test set: Average loss: 308.7261
# Communication time over the network 0.07 s
#
# Epoch Number 74
# Test set: Average loss: 326.6076
# Communication time over the network 0.07 s
#
# Epoch Number 75
# Test set: Average loss: 290.7334
# Communication time over the network 0.08 s
#
# Epoch Number 76
# Test set: Average loss: 304.7017
# Communication time over the network 0.07 s
#
# Epoch Number 77
# Test set: Average loss: 335.0959
# Communication time over the network 0.07 s
#
# Epoch Number 78
# Test set: Average loss: 319.0283
# Communication time over the network 0.07 s
#
# Epoch Number 79
# Test set: Average loss: 326.4104
# Communication time over the network 0.07 s
#
# Epoch Number 80
# Test set: Average loss: 318.4937
# Communication time over the network 0.07 s
#
# Epoch Number 81
# Test set: Average loss: 313.7060
# Communication time over the network 0.07 s
#
# Epoch Number 82
# Test set: Average loss: 327.2163
# Communication time over the network 0.07 s
#
# Epoch Number 83
# Test set: Average loss: 311.0803
# Communication time over the network 0.07 s
#
# Epoch Number 84
# Test set: Average loss: 290.8140
# Communication time over the network 0.08 s
#
# Epoch Number 85
# Test set: Average loss: 314.1602
# Communication time over the network 0.07 s
#
# Epoch Number 86
# Test set: Average loss: 318.8696
# Communication time over the network 0.07 s
#
# Epoch Number 87
# Test set: Average loss: 297.5506
# Communication time over the network 0.07 s
#
# Epoch Number 88
# Test set: Average loss: 310.9688
# Communication time over the network 0.07 s
#
# Epoch Number 89
# Test set: Average loss: 300.7813
# Communication time over the network 0.07 s
#
# Epoch Number 90
# Test set: Average loss: 309.5318
# Communication time over the network 0.07 s
#
# Epoch Number 91
# Test set: Average loss: 328.2370
# Communication time over the network 0.07 s
#
# Epoch Number 92
# Test set: Average loss: 301.3773
# Communication time over the network 0.08 s
#
# Epoch Number 93
# Test set: Average loss: 323.5293
# Communication time over the network 0.07 s
#
# Epoch Number 94
# Test set: Average loss: 313.9073
# Communication time over the network 0.07 s
#
# Epoch Number 95
# Test set: Average loss: 311.5500
# Communication time over the network 0.07 s
#
# Epoch Number 96
# Test set: Average loss: 312.3061
# Communication time over the network 0.07 s
#
# Epoch Number 97
# Test set: Average loss: 330.9074
# Communication time over the network 0.08 s
#
# Epoch Number 98
# Test set: Average loss: 302.8421
# Communication time over the network 0.07 s
#
# Epoch Number 99
# Test set: Average loss: 323.5280
# Communication time over the network 0.07 s
#
# Epoch Number 100
# Test set: Average loss: 315.4713
# Communication time over the network 0.07 s
